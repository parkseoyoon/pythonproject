# %% [raw]
# quiz 01>
# 주민등록번호 14자리를 입력받아서 성별을 체크합니다.
# 프로그램 종료는 (q,Q)를 누를 때까지 반복체크합니다.
# 입력예: 123456-1234567
# 조건처리: - 길이값 체크
#          - 성별 체크(가능값:1,2,3,4)
# 출력: 여성입니다. or 남성입니다.

# %%
while num:
    num = input('주민등록번호를 입력하세요 : ')
    if num in ['q', 'Q']:
        break
    elif int(num[7]) in [1, 3]:
        print('남성입니다.')
    elif int(num[7]) in [2, 4]:
        print('여성입니다.')
    else :
        print('주민등록번호가 잘못 입력되었습니다.')
# Out:
# 주민등록번호를 입력하세요 :  980220-2754628
# 여성입니다.
# 주민등록번호를 입력하세요 :  885556-423689
# 여성입니다.
# 주민등록번호를 입력하세요 :  55568-355654
# 주민등록번호가 잘못 입력되었습니다.
# 주민등록번호를 입력하세요 :  556548-123468
# 남성입니다.
# 주민등록번호를 입력하세요 :  Q

# %%
while True:
    invalue = input('주민등록번호 입력(14자리, 종료:q,Q) >>> ')
    if len(invalue) == 1 and invalue.lower() == 'q' :
        print('프로그램 종료')
        break
    elif len(invalue) == 14 and invalue[6] == '-' and invalue[7] in ['1','2','3','4']:
        if invalue[7] in ['1', '3']:
            print('남성입니다.')
        else:
            print('여성입니다.')
    else:
        print('입력 문자의 길이가 안맞거나, 성별값의 범위가 아닙니다.')
# Out:
# 주민등록번호 입력(14자리, 종료:q,Q) >>>  123456-1234567
# 남성입니다.
# 주민등록번호 입력(14자리, 종료:q,Q) >>>  12346-2456789
# 입력 문자의 길이가 안맞거나, 성별값의 범위가 아닙니다.
# 주민등록번호 입력(14자리, 종료:q,Q) >>>  123456-265958
# 입력 문자의 길이가 안맞거나, 성별값의 범위가 아닙니다.
# 주민등록번호 입력(14자리, 종료:q,Q) >>>  123456-2369876
# 여성입니다.
# 주민등록번호 입력(14자리, 종료:q,Q) >>>  q
# 프로그램 종료

# %% [raw]
# quiz 02>
# 로또 번호 추출기
# 총 5세트의 번호를 추출합니다.
# 한 세트당 번호는 6개입니다.
# 번호는 1~45 사이의 번호만 가능합니다.
# 번호는 중복되면 안됩니다.
# 번호를 출력시 오름차순으로 정렬해서 출력합니다.

# %%
import random #랜덤 함수 추가

# %%
random.random() #0과 1사이의 값 랜덤 추출
# Out:
# 0.923559850867826

# %%
random.randint(1,45) #범위 (a,b)사이의 값 랜덤 추출
# Out:
# 7

# %%
a = [2,4,5,1]
a.sort() #정렬
a
# Out:
# [1, 2, 4, 5]

# %%
lotto = []
while len(lotto) <= 6:
    num = random.randint(1, 45)
    if num not in lotto:
        lotto.append(num)
        if len(lotto) == 6:
            lotto.sort()
            print('추출된 로또번호 : ',lotto)
            break
# Out:
# 추출된 로또번호 :  [2, 4, 8, 19, 39, 43]

# %%
for i in range(5):
    lotto = []
    while len(lotto) <= 6:
        num = random.randint(1, 45)
        if num not in lotto:
            lotto.append(num)
            if len(lotto) == 6:
                lotto.sort()
                print('추출된 로또번호 : ',lotto)
# Out:
# 추출된 로또번호 :  [7, 15, 17, 19, 22, 44]
# 추출된 로또번호 :  [4, 27, 30, 32, 38, 40]
# 추출된 로또번호 :  [1, 10, 15, 19, 25, 39]
# 추출된 로또번호 :  [4, 5, 16, 24, 25, 43]
# 추출된 로또번호 :  [1, 5, 8, 26, 36, 42]

# %%
#강사님
import random
for i in range(5):
    lotto = [0, 0, 0, 0, 0, 0]
    for x in range(6):
        num = 0
        while (num in lotto):
            num = random.randint(1, 45)
        lotto[x] = num
    lotto.sort()
    print(lotto)
# Out:
# [1, 7, 13, 23, 28, 34]
# [15, 24, 26, 29, 30, 43]
# [4, 10, 13, 26, 29, 37]
# [2, 8, 14, 18, 21, 36]
# [5, 11, 19, 33, 36, 37]

# %%
#간단하게 random.sample 이용
for i in range(6):
    lotto = random.sample(range(1, 46), 6)
    lotto.sort()
    print(lotto)
# Out:
# [11, 19, 22, 23, 34, 43]
# [15, 22, 34, 38, 39, 42]
# [3, 6, 22, 28, 33, 37]
# [1, 9, 13, 16, 25, 35]
# [2, 15, 18, 26, 30, 44]
# [4, 13, 14, 22, 26, 28]

# %% [raw]
# quiz 03> 커피메뉴 관리프로그램
# 데이터 저장은 딕셔너리로..ex){'메뉴명': 가격, 'coffee':2000}
# 프로그램에서 사용할 메뉴
#  1. 메뉴입력 2. 메뉴수정 3. 메뉴목록 4. 메뉴삭제 5. 프로그램종료
#  - 메뉴입력 : 메뉴명과 가격을 입력받아서 저장
#  - 메뉴수정 : 메뉴명을 확인하고 있는 메뉴에 가격을 입력받아 수정
#  - 메뉴목록 : 저장된 메뉴명과 가격을 출력 (천 단위 구분기호 표기), 메뉴명 순서대로 출력(가나다 순)
#  - 메뉴삭제 : 메뉴명을 확인하고 있는 메뉴에서 삭제
#  - 프로그램 종료 : 프로그램을 종료하는 메시지를 출력하고 종료
#  - 메뉴1~5까지만 입력받고 다른 값이 들어오면 관련 에러 메시지를 출력한다.
#  - 가격은 숫자로 입력해야됨

# %%
#가나다 정렬 sorted()
list1 = [5, 2, 3, 1, 4]
dict1 = {'아이스아메리카노' : 3000, '라떼' : 4000, '코코아' : 3500}

# %%
sorted(list1) #정렬한 값을 return
# Out:
# [1, 2, 3, 4, 5]

# %%
list1 #원본은 손 안대짐
# Out:
# [5, 2, 3, 1, 4]

# %%
sorted(dict1.items())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/2447459985.py in <module>
# ----> 1 sorted(dict1.items()).dict()
#
# AttributeError: 'list' object has no attribute 'dict'

# %%
dict.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/1045209575.py in <module>
# ----> 1 dict.sort()
#
# AttributeError: type object 'dict' has no attribute 'sort'

# %%
sorted(dict1.items(), key=lambda data:data[1]) #lambda
# Out:
# [('아이스아메리카노', 3000), ('코코아', 3500), ('라떼', 4000)]

# %%
student_tu = [('john', 'A', 15),
              ('jane', 'B', 12),
              ('dave', 'B', 10)]

# %%
sorted(student_tu) #이름순 정렬
# Out:
# [('dave', 'B', 10), ('jane', 'B', 12), ('john', 'A', 15)]

# %%
sorted(student_tu, key=lambda x : x[2]) #x[2]나이, 나이순 정렬
# Out:
# [('dave', 'B', 10), ('jane', 'B', 12), ('john', 'A', 15)]

# %%
print(sorted(student_tu, key=lambda x : x[2], reverse=True)) #나이 역순 정렬
# Out:
# [('john', 'A', 15), ('jane', 'B', 12), ('dave', 'B', 10)]

# %%
#나 #실패
while True :
    category = input('무엇을 하시겠습니까?\n(카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) : ')    
    menu = {}
    if category == '1' :
        name = input('메뉴명을 입력하세요 : ')
        price = input('가격을 입력하세요 : ')
        menu[name] = price
    
    elif category == '2' :
        print(list(menu.keys()))
        name = input('가격을 수정할 메뉴명을 입력하세요 : ')
        if name in menu.keys():
            price = input('수정할 가격을 입력하세요 : ')
            menu[name] = price
        else :
            print('존재하지 않는 메뉴입니다.')
   
    elif category == '3' :
        menu = sorted(menu.items()) #천단위 표시
        print('메뉴목록입니다. ', menu)
    
    elif category == '4' :
        print(list(menu.keys()))
        name = input('삭제할 메뉴명을 입력하세요 : ')
        if name in menu.keys():
            del[name]
        else :
            print('존재하지 않는 메뉴입니다.')
        
    elif category == '5' :
        print('프로그램을 종료합니다.')
        break
        
    else :
        print('유효하지 않은 카테고리입니다.')
# Out:
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  1.
# 유효하지 않은 카테고리입니다.
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  1
# 메뉴명을 입력하세요 :  아메
# 가격을 입력하세요 :  3000
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  라
# 유효하지 않은 카테고리입니다.
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  1000
# 유효하지 않은 카테고리입니다.
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  2
# []
# 가격을 수정할 메뉴명을 입력하세요 :  5
# 존재하지 않는 메뉴입니다.
# 무엇을 하시겠습니까?
# (카테고리 : 메뉴입력 = 1, 메뉴수정 = 2, 메뉴목록 = 3, 메뉴삭제 = 4, 프로그램 종료 = 5) :  5
# 프로그램을 종료합니다.

# %%
menu = {'커피' : 5000, '라떼' : 3000, '아이스' :1000}
menu.keys()
# Out:
# dict_keys(['커피', '라떼', '아이스'])

# %%
menu = {}

# %%
menu[1]=3

# %%
#나 
menu = {'아메리카노' : 3000, '라떼' : 1000}
while True :
    category = input('무엇을 하시겠습니까?\n(카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) : ')    
    
    if category == '1' :
        name = input('메뉴명을 입력하세요 : ')
        price = 'a'
        while not price.isdecimal():
            price = input('가격을 입력하세요 : ')
        menu[name] = int(price)
    
    elif category == '2' :
        print('메뉴 목록입니다.', list(menu.keys()))
        name = input('가격을 수정할 메뉴명을 입력하세요 : ')
        if name in menu.keys():
            price = 'a'
            while not price.isdecimal():
                price = input('수정할 가격을 입력하세요 : ')
            menu[name] = int(price)
        else :
            print('존재하지 않는 메뉴입니다.')
   
    elif category == '3' :
        print('<메뉴판>')
        for item in sorted(menu.items()):
            print(f'{item[0]} {item[1]:,}')
    
    elif category == '4' :
        print('메뉴 목록입니다.', list(menu.keys()))
        name = input('삭제할 메뉴명을 입력하세요 : ')
        if name in menu.keys():
            del[name]
        else :
            print('존재하지 않는 메뉴입니다.')
        
    elif category == '5' :
        print('프로그램을 종료합니다.')
        break
        
    else :
        print('유효하지 않은 카테고리입니다.')
# Out:
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  2
# 메뉴 목록입니다. ['아메리카노', '라떼']
# 가격을 수정할 메뉴명을 입력하세요 :  라떼
# 수정할 가격을 입력하세요 :  1000
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  3
# <메뉴판>
# 라떼 1,000
# 아메리카노 3,000
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  4
# 메뉴 목록입니다. ['아메리카노', '라떼']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/4268310953.py in <module>
#      29     elif category == '4' :
#      30         print('메뉴 목록입니다.', list(menu.keys()))
# ---> 31         name = input('삭제할 메뉴명을 입력하세요 : ')
#      32         if name in menu.keys():
#      33             del[name]
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
menu = {'아메리카노' : 3000, '라떼' : 1000}
while True :
    category = input('무엇을 하시겠습니까?\n(카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) : ')    
    
    if category == '1' :
        name = input('메뉴명을 입력하세요 : ')
        price = 'a'
        while not price.isdecimal():
            price = input('가격을 입력하세요 : ')
        menu[name] = int(price)
    
    elif category == '2' :
        print('메뉴 목록입니다.', list(menu.keys()))
        name = ''
        while not name in menu.keys():
            name = input('가격을 수정할 메뉴명을 입력하세요 : ')
        price = 'a'
        while not price.isdecimal():
            price = input('수정할 가격을 입력하세요 : ')
        menu[name] = int(price)
   
    elif category == '3' :
        print('<메뉴판>')
        for item in sorted(menu.items()):
            print(f'{item[0]} {item[1]:,}')
    
    elif category == '4' :
        print('메뉴 목록입니다.', list(menu.keys()))
        name = ''
        while not name in menu.keys():
            name = input('삭제할 메뉴명을 입력하세요 : ')
        del[name]
        
    elif category == '5' :
        print('프로그램을 종료합니다.')
        break
        
    else :
        print('유효하지 않은 카테고리입니다.')
# Out:
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  1
# 메뉴명을 입력하세요 :  라
# 가격을 입력하세요 :  300
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  2
# 메뉴 목록입니다. ['아메리카노', '라떼', '라']
# 가격을 수정할 메뉴명을 입력하세요 :  라
# 수정할 가격을 입력하세요 :  5000
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  3
# <메뉴판>
# 라 5,000
# 라떼 1,000
# 아메리카노 3,000
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  4
# 메뉴 목록입니다. ['아메리카노', '라떼', '라']
# 삭제할 메뉴명을 입력하세요 :  라
# 무엇을 하시겠습니까?
# (카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) :  3
# <메뉴판>
# 라 5,000
# 라떼 1,000
# 아메리카노 3,000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/98813281.py in <module>
#       1 menu = {'아메리카노' : 3000, '라떼' : 1000}
#       2 while True :
# ----> 3     category = input('무엇을 하시겠습니까?\n(카테고리 : 1.메뉴입력, 2.메뉴수정, 3.메뉴목록, 4.메뉴삭제, 5.프로그램 종료) : ')
#       4
#       5     if category == '1' :
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
##### 강사님
menu = {'아이스아메리카노' : 3000, '라떼' : 4000, '코코아' : 3500}
while True:
    choice= input('''
-------------------------------------------------------------
1. 메뉴입력 2. 메뉴수정 3. 메뉴목록 4. 메뉴삭제 5. 프로그램종료
-------------------------------------------------------------
메뉴선택 >>> ''')
    if choice == '1':
        print('현재메뉴 :', list(menu.keys()))
        name = input('추가할 메뉴명을 입력하세요 >>> ')
        price = 'a'
        while not price.isdecimal():
            price = input('추가할 메뉴의 가격을 입력하세요 >>> ')
        menu[name] = int(price)
    elif choice == '2':
        print('현재메뉴 :', list(menu.keys()))
        name = ''
        while not name in menu.keys():
            name = input('수정할 메뉴명을 입력하세요 >>> ')
        price = 'a'
        while not price.isdecimal():
            price = input('수정할 메뉴의 가격을 입력하세요 >>> ')
        menu[name] = int(price)
    elif choice == '3':
        print('----- menu -----')
        for item in sorted(menu.items()):
            print(f'{item[0]} : {item[1]:10,}') #10,에서 콤마가 천단위 구분
    elif choice == '4':
        print('현재메뉴 :', list(menu.keys()))
        name = ''
        while not name in menu.keys():
            name = input('삭제할 메뉴명을 입력하세요 >>> ')
        del menu[name]
    elif choice == '5' :
        print('프로그램을 종료합니다.')
        break
    else:
         print('메뉴를 잘못 선택하셨습니다.')
# Out:
# -------------------------------------------------------------
# 1. 메뉴입력 2. 메뉴수정 3. 메뉴목록 4. 메뉴삭제 5. 프로그램종료
# -------------------------------------------------------------
# 메뉴선택 >>>  3
# ----- menu -----
# 라떼 :      4,000
# 아이스아메리카노 :      3,000
# 코코아 :      3,500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12048/999620400.py in <module>
#       2 menu = {'아이스아메리카노' : 3000, '라떼' : 4000, '코코아' : 3500}
#       3 while True:
# ----> 4     choice= input('''
#       5 -------------------------------------------------------------
#       6 1. 메뉴입력 2. 메뉴수정 3. 메뉴목록 4. 메뉴삭제 5. 프로그램종료
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [raw]
# quiz 04>
# quiz 03에 내용을 저장하고 읽기

# %%
file = open('hello.txt', 'w')  #r:읽기모드(파일이 있어야 동작), w:쓰기모드(파일을 새로 만듦)

# %%
file.write('hello world!')
# Out:
# 12

# %%
file.close() #무조건 해줘야 함

# %%
file = open('hello.txt','r')
text = file.read()

# %%
text
# Out:
# 'hello world!\nhello world!\nhello world!\nhello world!\nhello world!\nhello world!\nhello world!'

# %%
file = open('hello.txt','r')
textline = file.readline() #한 줄만 읽어옴
textline
# Out:
# 'hello world!\n'

# %%
file = open('hello.txt','r')
textlines = file.readlines() #줄별로 띄워서 모두 읽어옴
textlines
# Out:
# ['hello world!\n',
#  'hello world!\n',
#  'hello world!\n',
#  'hello world!\n',
#  'hello world!\n',
#  'hello world!\n',
#  'hello world!']

# %%
file.close()
